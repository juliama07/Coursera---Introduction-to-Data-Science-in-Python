# %% [markdown]
# # Overview of Python

# %% [markdown]
# ## Python functions, types and sequences, strings

# %%
[1, 2] + [3, 4]
# Out:
# [1, 2, 3, 4]

# %%
x = "changed"
print(x[0:2])
# Out:
# ch

# %%
x[-1]
# Out:
# 'd'

# %%
x[-2:-1]
# Out:
# 'e'

# %%
4 in [1, 2, 4]
[1, 2] in [1, 2, 4]
# Out:
# False

# %%
"remain" + str("0")
# Out:
# 'remain0'
