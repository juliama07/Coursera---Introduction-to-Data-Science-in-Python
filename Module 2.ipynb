# %% [markdown]
# # Series

# %%
# %pip install pandas
import pandas as pd
seriesa = pd.Series( [10, 20, 30] )
sorted(seriesa)
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.9 MB 11.3 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 10.0 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 8.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 8.6 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/9.9 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 7.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/12.6 MB 7.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.6 MB 6.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.6 MB 5.8 MB/s eta 0:00:02
# ...

# %%
seriesa[0]

# %%
seriesa.loc(0)

# %%
seriesa + seriesa

# %%
list(zip(seriesa))

# %% [markdown]
# # Dataframe

# %%
data = pd.DataFrame({
    "Product": ["Pearls", "Cup", "Tea"],
    "Price": [100, 25, 300],
})

# %%
# Unsure of usage data.query("Product = Pearls")

# %%
data.shape
# Out:
# (3, 2)

# %%
data.columns
# Out:
# Index(['Product', 'Price'], dtype='str')

# %%
data.iloc[2:3]
